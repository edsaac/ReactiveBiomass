# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(f'/home/edsaa/Repositories/ReactiveBiomass/misc/edwin.mplstyle')

# %%
data = pd.read_csv("reviewedProfile.csv")

# %%
Y = data['Points:1']
data.head()
# Out:
#         BAP       DOC       EPS       NH4       NO3        O2      POCr  \
# 0  0.000133  0.000176  0.000028  0.000005  0.000368  0.001574  0.000106
# 1  0.000139  0.000183  0.000029  0.000005  0.000382  0.001637  0.000110
# 2  0.000141  0.000186  0.000030  0.000005  0.000389  0.001665  0.000112
# 3  0.000141  0.000186  0.000030  0.000005  0.000390  0.001668  0.000111
# 4  0.000142  0.000187  0.000030  0.000005  0.000392  0.001677  0.000111
#
#             U:0           U:1           U:2  ...          perm       rDN  \
# 0 -7.919000e-12 -7.396600e-12 -4.483900e-29  ...  9.742700e-12  0.000002
# 1 -8.497600e-12 -1.550400e-11 -3.968100e-29  ...  1.011600e-11  0.000002
# 2 -8.874700e-12 -2.743300e-11  2.350500e-29  ...  1.025900e-11  0.000003
# 3 -9.100700e-12 -4.238000e-11  1.144900e-28  ...  1.022200e-11  0.000003
# 4 -9.386100e-12 -5.728600e-11  7.856800e-29  ...  1.020200e-11  0.000003
#
#              rH            rN  cellID  vtkValidPointMask  arc_length  \
# ...

# %%
fig,ax = plt.subplots(figsize=[5,6])
fields = ['DOC','O2','NO3','NH4']
ax.plot(data[fields],Y,label=fields)
ax.set(xscale='log')
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[5,6])
fields = ['rH','rN','rDN']
ax.plot(data[fields],Y,label=fields)
ax.set(xscale='log')
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[5,6])
ax.fill_betweenx(Y,data['XN'] + data['XDN'] + data['XAR'],x2=0 ,label='XAR')
ax.fill_betweenx(Y,data['XN'] + data['XDN'],x2=0 , label='XN')
ax.fill_betweenx(Y,data['XDN'],x2=0 , label='XDN')
ax.plot(data['O2'],Y)
ax.set(xscale='log')
ax.legend(loc='lower right')
plt.show()
