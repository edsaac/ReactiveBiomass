# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pathToData = "./plotExperiment/data/Table1.csv"
dataExperiment = pd.read_csv(pathToData,skiprows=3)

# %%
dataExperiment.insert(0, 'DATE TIME', pd.to_datetime(dataExperiment['TIMESTAMPTS'] + " " + dataExperiment['RECORDRN']))

# %%
dataExperiment.drop(columns=['TIMESTAMPTS','RECORDRN','time (min)'],inplace=True)

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'orp' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data[:5])
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'VWC' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data[:5])
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'Temp' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data[:6])
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'pH' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data[:4])
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'inflow' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data)
ax.legend()
plt.show()

# %%
fig,ax = plt.subplots(figsize=[8,6])
for data in dataExperiment:
    if 'Head' in data:
        ax.plot(dataExperiment['DATE TIME'],dataExperiment[data],label=data)
ax.legend()
plt.show()
