# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pathToData = "~/Dropbox/BIRD-SAT-shared/Lab experiments - Ido Arad/DP (20.12.21)/Table 1_20.12.xlsx"
pd.read_excel(pathToData)
# Out:
#                      TOA5        CR  Unnamed: 2  Unnamed: 3  84397  \
# 0               TIMESTAMP    RECORD         NaN         NaN  orp_a
# 1                      TS        RN         NaN         NaN     mv
# 2                     NaN       NaN  time (min)  time (hr.)    Smp
# 3     2021-12-20 00:00:00  11:10:00           0           0  318.9
# 4     2021-12-20 00:00:00  11:11:00           1    0.016667  318.8
# ...                   ...       ...         ...         ...    ...
# 4319  2021-12-23 00:00:00  11:06:00        4316   71.933333 -211.8
# 4320  2021-12-23 00:00:00  11:07:00        4317       71.95 -212.1
# 4321  2021-12-23 00:00:00  11:08:00        4318   71.966667 -212.2
# 4322  2021-12-23 00:00:00  11:09:00        4319   71.983333 -212.6
# 4323  2021-12-23 00:00:00  11:10:00        4320          72 -212.9
#
#      CR1000.Std.31 CPU:arad.CR1  39849 Table1 Unnamed: 9  ... Unnamed: 11  \
# 0            orp_b        orp_c  orp_d   pH_1       pH_2  ...        Head
# ...
